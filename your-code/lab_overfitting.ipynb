# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#In-this-lab,-we-are-going-to-explore-how-thoughtfully-choosing-a-model-and-using-test-set-are-important-parts-of-avoiding-overfitting." data-toc-modified-id="In-this-lab,-we-are-going-to-explore-how-thoughtfully-choosing-a-model-and-using-test-set-are-important-parts-of-avoiding-overfitting.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>In this lab, we are going to explore how thoughtfully choosing a model and using test set are important parts of avoiding overfitting.</a></span><ul class="toc-item"><li><span><a href="#First,-we-are-going-to-generate-some-synthetic-data.-To-make-these-concepts-visual,-we-are-going-to-generate-this-data-to-be-concentric-circles.-Run-the-code-below-to-do-so." data-toc-modified-id="First,-we-are-going-to-generate-some-synthetic-data.-To-make-these-concepts-visual,-we-are-going-to-generate-this-data-to-be-concentric-circles.-Run-the-code-below-to-do-so.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>First, we are going to generate some synthetic data. To make these concepts visual, we are going to generate this data to be concentric circles. Run the code below to do so.</a></span></li><li><span><a href="#As-our-classification-algorithm,-we-are-going-to-use-a-type-of-SVM-with-a-radial-basis-function.-This-basically-works-by-mapping-each-point-into-a-higher-dimensional-space-that-can-be-split-by-the-SVM-(gross-oversimplificaiton).-That-looks-something-like-this:" data-toc-modified-id="As-our-classification-algorithm,-we-are-going-to-use-a-type-of-SVM-with-a-radial-basis-function.-This-basically-works-by-mapping-each-point-into-a-higher-dimensional-space-that-can-be-split-by-the-SVM-(gross-oversimplificaiton).-That-looks-something-like-this:-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>As our classification algorithm, we are going to use a type of SVM with a radial basis function. This basically works by mapping each point into a higher dimensional space that can be split by the SVM (gross oversimplificaiton). That looks something like this:</a></span></li><li><span><a href="#We-can-change-thecomplexity-of-the-decision-boundaries-applied-by-the-SVM-by-changing-the-size-of-the-radial-basis-function,-through-the-parameter-'gamma'." data-toc-modified-id="We-can-change-thecomplexity-of-the-decision-boundaries-applied-by-the-SVM-by-changing-the-size-of-the-radial-basis-function,-through-the-parameter-'gamma'.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>We can change thecomplexity of the decision boundaries applied by the SVM by changing the size of the radial basis function, through the parameter 'gamma'.</a></span></li><li><span><a href="#Now,-we-are-going-to-plot-the-boundaries-created-by-each-of-these-classifiers-with-the-points-we-generated.-Run-the-following-code-to-make-three-graphs-of-each-SVM-classifier." data-toc-modified-id="Now,-we-are-going-to-plot-the-boundaries-created-by-each-of-these-classifiers-with-the-points-we-generated.-Run-the-following-code-to-make-three-graphs-of-each-SVM-classifier.-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Now, we are going to plot the boundaries created by each of these classifiers with the points we generated. Run the following code to make three graphs of each SVM classifier.</a></span></li><li><span><a href="#Where-the-contour-is-red,-we-will-predict-red,-and-same-for-blue;-white-means-there-is-a-50/50-chance-of-either-class" data-toc-modified-id="Where-the-contour-is-red,-we-will-predict-red,-and-same-for-blue;-white-means-there-is-a-50/50-chance-of-either-class-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Where the contour is red, we will predict red, and same for blue; white means there is a 50/50 chance of either class</a></span></li><li><span><a href="#Without-having-used-a-training-and-testing-set,-lets-see-what-our-accuracy-score-would-be-for,-for-example,-a-gamma-of-.7." data-toc-modified-id="Without-having-used-a-training-and-testing-set,-lets-see-what-our-accuracy-score-would-be-for,-for-example,-a-gamma-of-.7.-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Without having used a training and testing set, lets see what our accuracy score would be for, for example, a gamma of .7.</a></span></li><li><span><a href="#Wow-thats-good-accuracy!-But-is-it-generalizable?-Make-a-test/train-split-and-see-how-the-model-performs-on-the-SVM-with-the-gamma-of-20." data-toc-modified-id="Wow-thats-good-accuracy!-But-is-it-generalizable?-Make-a-test/train-split-and-see-how-the-model-performs-on-the-SVM-with-the-gamma-of-20.-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Wow thats good accuracy! But is it generalizable? Make a test/train split and see how the model performs on the SVM with the gamma of 20.</a></span></li><li><span><a href="#Try-with-some-of-the-other-gammas-to-see-how-the-accuracy-score-changes-after-implementing-a-test/train-split." data-toc-modified-id="Try-with-some-of-the-other-gammas-to-see-how-the-accuracy-score-changes-after-implementing-a-test/train-split.-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Try with some of the other gammas to see how the accuracy score changes after implementing a test/train split.</a></span></li><li><span><a href="#Was-your-previous-model-overfitting?-If-so,-how-would-you-try-to-improve-this-model-to-prevent-this?" data-toc-modified-id="Was-your-previous-model-overfitting?-If-so,-how-would-you-try-to-improve-this-model-to-prevent-this?-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Was your previous model overfitting? If so, how would you try to improve this model to prevent this?</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Overfitting
# ## In this lab, we are going to explore how thoughtfully choosing a model and using test set are important parts of avoiding overfitting.
#
# We are going to apply these concepts to a classification model. We want to develop a decision boundary, on one side of which we have class A and on the other we have class B.
#
# Like we disussed in class, when we have noisy data, if we are not careful, we can end up fitting our model to the noise in the data and not the 'signal'-- the factors that actually determine the outcome. This is called overfitting, and results in good results in training, and in bad results when the model is applied to real data. Similarly, we could have a model that is too simplistic to accurately model the signal. This produces a model that doesnt work well (ever), and sucks only slightly less than overfitting. At least your model performs consistently bad :)

# %% [markdown]
# ### First, we are going to generate some synthetic data. To make these concepts visual, we are going to generate this data to be concentric circles. Run the code below to do so.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display

# Makin' some data
from sklearn.datasets import make_circles
X, y = make_circles(noise=0.2, factor=0.5, random_state=1)

# %% [markdown]
# ### As our classification algorithm, we are going to use a type of SVM with a radial basis function. This basically works by mapping each point into a higher dimensional space that can be split by the SVM (gross oversimplificaiton). That looks something like this:
# ![RBFSVM.png](../images/RBFSVM.png)

# %% [markdown]
# ### We can change thecomplexity of the decision boundaries applied by the SVM by changing the size of the radial basis function, through the parameter 'gamma'.
#
# Instantiate a list of three SVM classifiers with three different gamma parameters, (.001, 1, and 20). Use *SVC* (Support Vector Classification) ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC)).
# Assign the list of classifiers to the variable *classifiers*.

# %%
# Your code here
from sklearn.svm import SVC
classifiers = [SVC(gamma=.001), SVC(gamma=1), SVC(gamma=20)]

# %% [markdown]
# ### Now, we are going to plot the boundaries created by each of these classifiers with the points we generated. Run the following code to make three graphs of each SVM classifier.

# %%
from matplotlib.colors import ListedColormap

figure = plt.figure(figsize=(12, 6))
i = 1
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])
names = ['gamma = 0.001', 'gamma = 1', 'gamma = 20']

# iterate over classifiers
for name, clf in zip(names, classifiers):
    ax = plt.subplot(1, len(classifiers), i)
    clf.fit(X, y)

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    if hasattr(clf, "decision_function"):
        Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
    else:
        Z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, cmap=cm, alpha=.8)

    ax.scatter(X[:, 0], X[:, 1], c=y, cmap=cm_bright)

    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_title(name)
    i += 1
plt.show()

# %% [markdown]
# ### Where the contour is red, we will predict red, and same for blue; white means there is a 50/50 chance of either class
# Explain what you see in the plots above.
#
# Which gamma do you think fits the data best?
#
# What would you select as the optimal gamma?

# %%
# Your response here

# %% [markdown]
# ### Without having used a training and testing set, lets see what our accuracy score would be for, for example, a gamma of .7.
# Instantiate a new SVC with that gamma, and fit the entire dataset (X, y). Use the .score() method of the SVC model to calculate the accuracy score of all the trained data.

# %%
# Your code here

# %% [markdown]
# ### Wow thats good accuracy! But is it generalizable? Make a test/train split and see how the model performs on the SVM with the gamma of 20.

# %%
# Your code here
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Out:
# Train accuracy: 0.975
# Test accuracy: 0.85

# %% [markdown]
# ### Try with some of the other gammas to see how the accuracy score changes after implementing a test/train split.

# %%
# Your code here
gammas = [0.5, 2, 4, 8, 12, 24, 50,  100, 200, 300, 400]
# Out:
# Gamma: 0.5
# Train accuracy: 0.8875
# Test accuracy: 0.8
# Gamma: 2
# Train accuracy: 0.925
# Test accuracy: 0.8
# Gamma: 4
# Train accuracy: 0.925
# Test accuracy: 0.8
# Gamma: 8
# Train accuracy: 0.95
# Test accuracy: 0.85
# Gamma: 12
# Train accuracy: 0.9625
# Test accuracy: 0.8
# Gamma: 24
# Train accuracy: 0.975
# Test accuracy: 0.85
# Gamma: 50
# Train accuracy: 0.9875
# Test accuracy: 0.85
# Gamma: 100
# Train accuracy: 1.0
# Test accuracy: 0.75
# Gamma: 200
# Train accuracy: 1.0
# Test accuracy: 0.6
# Gamma: 300
# Train accuracy: 1.0
# Test accuracy: 0.5
# Gamma: 400
# Train accuracy: 1.0
# Test accuracy: 0.45

# %% [markdown]
# ### Was your previous model overfitting? If so, how would you try to improve this model to prevent this?

# %%
# Your response here
